# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
random_int_array = np.random.randint(1, 50, size=(10))
random_int_array
# Out:
# array([48, 40, 24, 24, 25, 43, 39, 13, 39, 33], dtype=int32)

# %%
np.size(random_int_array)
# Out:
# 10

# %%
npArray = np.array(random_int_array)
npArray
# Out:
# array([48, 40, 24, 24, 25, 43, 39, 13, 39, 33], dtype=int32)

# %%
npArray.dtype
# Out:
# dtype('int32')

# %%
npArray.size
# Out:
# 10

# %%
npArray.ndim
# Out:
# 1

# %%
mat = np.random.randint(1 , 100, size=(2,5))
mat
# Out:
# array([[ 1, 28, 22, 56, 31],
#        [61, 44, 90, 19, 26]], dtype=int32)

# %%
npMat = np.array(mat)
npMat
# Out:
# array([[ 1, 28, 22, 56, 31],
#        [61, 44, 90, 19, 26]], dtype=int32)

# %%
npMat.shape
# Out:
# (2, 5)
